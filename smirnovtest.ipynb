# %%
import pandas as pd
import numpy as np
from scipy.stats import kstest
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('diamonds_new.xlsx')

# %%
data
# Out:
#        price  carat        cut color clarity  depth  table     x     y     z
# 0        326   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1        326   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2        327   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3        334   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4        335   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53915   2757   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53916   2757   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53917   2757   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53918   2757   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53919   2757   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53920 rows x 10 columns]

# %%
statistic, pvalue = kstest(data['price'], 'norm' ) 
print(f'P-Value: {pvalue}')

if pvalue<0.05:
    print('The data doesnot follow specified distribution')
# Out:
# P-Value: 0.0
# The data doesnot follow specified distribution

# %%
import scipy as stats
from scipy.stats import kruskal
p_value = kruskal(data['price'], data['carat'], data['clarity'])

if p_value > 0.05:
    print('null hypothesis is true')
else:
    print('reject null hypothesis')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
# ...

# %%
# Group data by 'cut' and perform Kruskal-Wallis test
cuts = [data[data['cut'] == cut]['price'] for cut in data['cut'].unique()]

# Perform Kruskal-Wallis H Test
stat, p_val = stats.kruskal(*cuts)

# Check p-value
print(f"Kruskal-Wallis H Test p-value: {p_val}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\__init__.py:149, in __getattr__(name)
#     148 try:
# --> 149     return globals()[name]
#     150 except KeyError:
#
# KeyError: 'kruskal'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       2 cuts = [data[data['cut'] == cut]['price'] for cut in data['cut'].unique()]
#       4 # Perform Kruskal-Wallis H Test
# ----> 5 stat, p_val = stats.kruskal(*cuts)
#       7 # Check p-value
#       8 print(f"Kruskal-Wallis H Test p-value: {p_val}")
#
# ...
